# %% [markdown]
# # MuRIL Fine-tuning on Google Colab (GPU)
#
# Use this notebook when local CPU training is too slow.
#
# 1. **Runtime → Change runtime type → GPU (T4)**
# 2. Upload your project folder or mount Google Drive
# 3. Run all cells

# %%
# Mount Drive (optional) — skip if you uploaded the folder directly
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/hinglish-sentiment

# %%
# Colab-only deps (avoids TensorFlow + peft/accelerate version conflicts)
# !pip install -q -r requirements-colab.txt

# %%
import torch
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None')

# %%
# clean_data.csv is already in the zip — no preprocess needed
import os
assert os.path.exists('data/processed/clean_data.csv'), 'Upload the full zip and cd into hinglish-sentiment'
print('Data OK:', os.path.getsize('data/processed/clean_data.csv'), 'bytes')

# %%
# Fine-tune MuRIL (5 epochs on GPU, ~20–30 min on T4)
# !python src/train.py --model muril

# %%
# Generate comparison figures + error analysis
# !python src/evaluate.py
# !python src/error_analysis.py
